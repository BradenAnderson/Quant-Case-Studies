# %%
from sensitive_info import *
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv("./data/CS7_preprocessed.csv")
df.head(2)
# Out:
#          x0        x1         x2        x3        x4        x5         x6  \
# 0 -0.166563 -3.961588   4.621113  2.481908 -1.800135  0.804684   6.718751
# 1 -0.149894 -0.585676  27.839856  4.152333  6.426802 -2.426943  40.477058
#
#           x7        x8        x9  ...        x41       x42       x43  \
# 0 -14.789997 -1.040673 -4.204950  ...  -1.497117  5.414063 -2.325655
# 1  -6.725709  0.896421  0.330165  ...  36.292790  4.490915  0.762561
#
#         x44       x45        x46       x47       x48        x49  y
# 0  1.674827 -0.264332  60.781427 -7.689696  0.151589  -8.040166  0
# 1  6.526662  1.007927  15.805696 -4.896678 -0.320283  16.719974  0
#
# [2 rows x 51 columns]

# %%
df = convert_strings_to_category(df)
df.info()

# %%
train_df, val_df, test_df = create_train_val_test_sets(df=df, 
                                                       target_column="y", 
                                                       test_size=0.1, 
                                                       val_size=0.1, 
                                                       random_state=7742)
# Out:
# Train Shape: (128000, 51)
# Val Shape: (16000, 51)
# Test Shape: (16000, 51)

# %%
X_train = train_df.drop(columns="y")
y_train = train_df.loc[:,"y"].to_numpy()

X_val = val_df.drop(columns="y")
y_val = val_df.loc[:,"y"].to_numpy()

X_test = test_df.drop(columns="y")
y_test = test_df.loc[:,"y"].to_numpy()

# Subset to features selected by DAI
X_train_dai, X_val_dai, X_test_dai = subset_to_dai_selected_features(X_train=X_train, 
                                                                     X_val=X_val, 
                                                                     X_test=X_test)
# Out:
# DAI Train Shape: (128000, 17)
# DAI Val Shape: (16000, 17)
# DAI Test Shape: (16000, 17)

# %%
X_train_dai.head(2)
# Out:
#              x48       x23        x27       x20        x28        x46  \
# 133862 -4.818280 -4.676670  10.352920  2.029764 -30.102992  32.780607
# 57143   3.102613  1.519396 -12.122562 -4.198570 -16.416524  55.582887
#
#               x49      x37       x42        x12   x32         x7        x2  \
# 133862 -14.191745   -72.62  0.582534 -10.735783  0.01 -15.072493  0.419611
# 57143   34.763313  1918.51  6.188595   9.566781  0.00   2.656567 -0.427442
#
#               x38        x41        x6        x40
# 133862 -24.254114 -26.823132  0.610082   3.604330
# 57143   23.569760  26.066290 -0.621469 -20.189674

# %%
scorers_dict = {"accuracy":make_scorer(accuracy_score), 
                "f025_score":make_scorer(fbeta_score, beta=0.25),
                "f05_score":make_scorer(fbeta_score, beta=0.5), 
                "avg_dollars_lost_per_prediction":make_scorer(score_func=average_dollars_scorer_sklearn, 
                                                              greater_is_better=False)}

# %%
# %%time 

mlp_pipe = Pipeline(steps=[("impute", SimpleImputer(strategy="mean")), 
                           ("scale", StandardScaler()),
                           ("model", MLPClassifier(random_state=7742, 
                                                   verbose=True, 
                                                   warm_start=True, 
                                                   early_stopping=True,
                                                   max_iter=100_000))])

mlp_grid = {"model__hidden_layer_sizes":[(200, 100,), (300, 200, 100,), 
                                         (400, 300, 200, 100), (512, 256, 128, 64,)], 
            "model__alpha":np.logspace(-7,-2, 20).tolist(), 
            "model__learning_rate_init":np.logspace(-5,-0.3, 40).tolist() + [0.01]}

cv_splitter = StratifiedKFold(n_splits=5, 
                              shuffle=True, 
                              random_state=7742)

gs_mlp = GridSearchCV(estimator=mlp_pipe, 
                  param_grid=mlp_grid, 
                  refit="avg_dollars_lost_per_prediction",
                  scoring=scorers_dict, 
                  cv=cv_splitter,
                  n_jobs=32, 
                  error_score="raise", 
                  return_train_score=True, 
                  verbose=2)

# gs_mlp.fit(X=X_train_dai, y=y_train)


# save_name = get_gs_save_name(model_name="MLP_SC")
# save_path=f"./models/{save_name}"
# with open(save_path, 'wb') as file:
#     pickle.dump(gs_mlp, file)

# PATH=f"./models/MLP_20221124_1303.pkl"
# gs_mlp = load_gs_from_pickle(pickle_filepath=PATH)

gs_df = gs_to_clean_df(gs_mlp.cv_results_, 
                       sort_metric="mean_test_avg_dollars_lost_per_prediction", 
                       sort_ascending=False)
gs_df.loc[:,[c for c in gs_df.columns if "std" not in c]].head()
# Out:
# Fitting 5 folds for each of 3280 candidates, totalling 16400 fits
# Iteration 1, loss = 0.20068362
# Validation score: 0.953281
# Iteration 2, loss = 0.13670806
# Validation score: 0.960781
# Iteration 3, loss = 0.11808104
# Validation score: 0.968125
# Iteration 4, loss = 0.10666698
# Validation score: 0.970781
# Iteration 5, loss = 0.10078183
# Validation score: 0.972969
# Iteration 6, loss = 0.09594607
# Validation score: 0.969844
# Iteration 7, loss = 0.09242462
# Validation score: 0.973281
# Iteration 8, loss = 0.08824939
# Validation score: 0.975313
# Iteration 9, loss = 0.08782944
# Validation score: 0.975469
# Iteration 10, loss = 0.08558967
# Validation score: 0.972969
# Iteration 11, loss = 0.08358750
# Validation score: 0.975859
# Iteration 12, loss = 0.08323828
# Validation score: 0.977187
# Iteration 13, loss = 0.08189735
# Validation score: 0.973125
# Iteration 14, loss = 0.08094009
# Validation score: 0.977656
# Iteration 15, loss = 0.08057543
# Validation score: 0.976016
# Iteration 16, loss = 0.07900717
# Validation score: 0.977109
# Iteration 17, loss = 0.07963616
# Validation score: 0.977422
# Iteration 18, loss = 0.07781486
# Validation score: 0.976172
# Iteration 19, loss = 0.07732921
# Validation score: 0.977422
# Iteration 20, loss = 0.07749244
# Validation score: 0.975234
# Iteration 21, loss = 0.07716773
# Validation score: 0.977969
# Iteration 22, loss = 0.07723131
# Validation score: 0.978516
# Iteration 23, loss = 0.07621673
# Validation score: 0.977812
# Iteration 24, loss = 0.07567495
# Validation score: 0.976016
# Iteration 25, loss = 0.07509565
# Validation score: 0.978047
# Iteration 26, loss = 0.07538303
# Validation score: 0.978359
# Iteration 27, loss = 0.07462200
# Validation score: 0.976719
# Iteration 28, loss = 0.07525276
# Validation score: 0.976406
# Iteration 29, loss = 0.07459407
# Validation score: 0.978047
# Iteration 30, loss = 0.07467963
# Validation score: 0.976641
# Iteration 31, loss = 0.07405124
# Validation score: 0.978437
# Iteration 32, loss = 0.07447491
# Validation score: 0.978672
# Iteration 33, loss = 0.07407290
# Validation score: 0.977969
# Iteration 34, loss = 0.07376861
# Validation score: 0.979531
# Iteration 35, loss = 0.07303741
# Validation score: 0.977500
# Iteration 36, loss = 0.07332409
# Validation score: 0.977812
# Iteration 37, loss = 0.07324420
# Validation score: 0.977969
# Iteration 38, loss = 0.07268997
# Validation score: 0.978672
# Iteration 39, loss = 0.07266667
# Validation score: 0.978750
# Iteration 40, loss = 0.07262488
# Validation score: 0.978281
# Iteration 41, loss = 0.07239797
# Validation score: 0.978359
# Iteration 42, loss = 0.07306347
# Validation score: 0.980000
# Iteration 43, loss = 0.07315297
# Validation score: 0.980234
# Iteration 44, loss = 0.07201151
# Validation score: 0.976719
# Iteration 45, loss = 0.07273042
# Validation score: 0.977422
# Iteration 46, loss = 0.07254953
# Validation score: 0.978750
# Iteration 47, loss = 0.07251458
# Validation score: 0.978203
# Iteration 48, loss = 0.07175068
# Validation score: 0.978047
# Iteration 49, loss = 0.07261837
# Validation score: 0.978984
# Iteration 50, loss = 0.07241838
# Validation score: 0.978281
# Iteration 51, loss = 0.07228048
# Validation score: 0.978359
# Iteration 52, loss = 0.07246882
# Validation score: 0.978516
# Iteration 53, loss = 0.07258522
# Validation score: 0.979062
# Iteration 54, loss = 0.07131888
# Validation score: 0.978516
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# CPU times: total: 2h 1min 11s
# Wall time: 1d 18h 32min 10s
#          alpha   hidden_layer_sizes learning_rate_init  \
# 3260      0.01  (512, 256, 128, 64)           0.003394
# 190        0.0           (200, 100)           0.013594
# 1787  0.000043  (512, 256, 128, 64)           0.007804
# 1545  0.000023      (300, 200, 100)           0.023679
# 3097  0.005456  (512, 256, 128, 64)            0.00448
#
#                                                  params  mean_test_accuracy  \
# 3260  {'model__alpha': 0.01, 'model__hidden_layer_si...            0.978914
# 190   {'model__alpha': 1.8329807108324375e-07, 'mode...            0.977586
# 1787  {'model__alpha': 4.281332398719396e-05, 'model...            0.977414
# 1545  {'model__alpha': 2.3357214690901213e-05, 'mode...            0.978250
# 3097  {'model__alpha': 0.005455594781168515, 'model_...            0.978977
#
#       rank_test_accuracy  mean_train_accuracy  mean_test_f025_score  \
# 3260                   3             0.983143              0.976775
# 190                  280             0.982436              0.977003
# 1787                 388             0.982721              0.976766
# 1545                  44             0.981723              0.976488
# 3097                   1             0.983002              0.976096
#
#       rank_test_f025_score  mean_train_f025_score  mean_test_f05_score  \
# 3260                     2               0.981537             0.975765
# 190                      1               0.982342             0.975363
# 1787                     3               0.982554             0.975134
# 1545                     4               0.980273             0.975297
# 3097                    13               0.980879             0.975337
#
#       rank_test_f05_score  mean_train_f05_score  \
# 3260                    1              0.980701
# 190                     2              0.980947
# 1787                    8              0.981209
# 1545                    4              0.979267
# 3097                    3              0.980201
#
#       mean_test_avg_dollars_lost_per_prediction  \
# 3260                                  -1.148594
# 190                                   -1.156406
# 1787                                  -1.167344
# 1545                                  -1.167500
# 3097                                  -1.173594
#
#       rank_test_avg_dollars_lost_per_prediction  \
# 3260                                          1
# 190                                           2
# 1787                                          3
# 1545                                          4
# 3097                                          5
#
#       mean_train_avg_dollars_lost_per_prediction
# 3260                                   -0.915430
# 190                                    -0.894414
# 1787                                   -0.882461
# 1545                                   -0.980859
# 3097                                   -0.941992

# %%
gs_df.sort_values(by="mean_test_accuracy").head(2)
# Out:
#          alpha    hidden_layer_sizes learning_rate_init  \
# 611   0.000001  (400, 300, 200, 100)           0.287723
# 2087  0.000144  (400, 300, 200, 100)           0.287723
#
#                                                  params  mean_test_accuracy  \
# 611   {'model__alpha': 6.158482110660267e-07, 'model...            0.598711
# 2087  {'model__alpha': 0.0001438449888287663, 'model...            0.598742
#
#       std_test_accuracy  rank_test_accuracy  mean_train_accuracy  \
# 611            0.000146                3280             0.598701
# 2087           0.000062                3277             0.598756
#
#       std_train_accuracy  mean_test_f025_score  ...  mean_test_f05_score  \
# 611             0.000151              0.003264  ...             0.000970
# 2087            0.000015              0.000659  ...             0.000194
#
#       std_test_f05_score  rank_test_f05_score  mean_train_f05_score  \
# 611             0.000920                 3219              0.000776
# 2087            0.000238                 3243              0.000340
#
#       std_train_f05_score  mean_test_avg_dollars_lost_per_prediction  \
# 611              0.000669                                  -8.036406
# 2087             0.000561                                  -8.028281
#
#       std_test_avg_dollars_lost_per_prediction  \
# 611                                   0.015282
# 2087                                  0.006060
#
#       rank_test_avg_dollars_lost_per_prediction  \
# 611                                        3156
# 2087                                       3148
#
#       mean_train_avg_dollars_lost_per_prediction  \
# 611                                    -8.036133
# 2087                                   -8.027852
#
#       std_train_avg_dollars_lost_per_prediction
# 611                                    0.019175
# 2087                                   0.005125
#
# [2 rows x 24 columns]

# %%
MODEL_NAME="Gridsearch MLP (Scaled)"
mlpsc_train_pred_df, mlpsc_val_pred_df = get_val_performance_after_all_train_refit(gs=gs_mlp, 
                                                                               X_train=X_train_dai, 
                                                                               y_train=y_train, 
                                                                               X_val=X_val_dai, 
                                                                               y_val=y_val, 
                                                                               model_name=MODEL_NAME)
# Out:
# ================= Gridsearch MLP (Scaled) =================
#
# accuracy: Train=0.9840859375, Validation=0.9788125
# f025_score: Train=0.9825588223779509, Validation=0.9806444405135414
# f05_score: Train=0.9817747248018651, Validation=0.9783054915211421
# avg_dollars_lost_per_prediction: Train=0.86453125, Validation=1.00375
# ===========================================================

# %%
gs_df["mean_test_avg_dollars_lost_per_prediction"].describe()
# Out:
# count    3280.000000
# mean       -2.592662
# std         2.359923
# min       -17.220313
# 25%        -2.106523
# 50%        -1.645234
# 75%        -1.342813
# max        -1.148594
# Name: mean_test_avg_dollars_lost_per_prediction, dtype: float64

# %%
# gs_mlp.best_params_

# %%
# %%time 

mlp_pipe = Pipeline(steps=[("impute", SimpleImputer(strategy="mean")), 
                           ("scale", StandardScaler()),
                           ("model", MLPClassifier(random_state=7742, 
                                                   verbose=True, 
                                                   warm_start=True, 
                                                   early_stopping=True,
                                                   max_iter=100_000))])

mlp_grid = {"model__hidden_layer_sizes":[(512, 256, 128, 64,), (1024, 512, 256, 128, 64,)], 
            "model__alpha":np.logspace(-2.1,-0.2, 20).tolist(), # Increased
            "model__learning_rate_init":np.logspace(-3,-2, 20).tolist() + [gs_mlp.best_params_['model__learning_rate_init']]}

cv_splitter = StratifiedKFold(n_splits=5, 
                              shuffle=True, 
                              random_state=7742)

gs_mlp2 = GridSearchCV(estimator=mlp_pipe, 
                  param_grid=mlp_grid, 
                  refit="avg_dollars_lost_per_prediction",
                  scoring=scorers_dict, 
                  cv=cv_splitter,
                  n_jobs=32, 
                  error_score="raise", 
                  return_train_score=True, 
                  verbose=2)

# gs_mlp2.fit(X=X_train_dai, y=y_train)


# save_name = get_gs_save_name(model_name="MLP_SC_Tune2")
# save_path=f"./models/{save_name}"
# with open(save_path, 'wb') as file:
#     pickle.dump(gs_mlp2, file)

# PATH=f"./models/MLP_20221124_1303.pkl"
# gs_mlp = load_gs_from_pickle(pickle_filepath=PATH)

gs_df2 = gs_to_clean_df(gs_mlp2.cv_results_, 
                       sort_metric="mean_test_avg_dollars_lost_per_prediction", 
                       sort_ascending=False)
gs_df2.loc[:,[c for c in gs_df2.columns if "std" not in c]].head()
# Out:
# Fitting 5 folds for each of 840 candidates, totalling 4200 fits
