# %%
from sensitive_info import *
pd.set_option("display.max.columns", 500)

# %%
df = pd.read_csv("./data/CS7_preprocessed.csv")
df.head(2)
# Out:
#          x0        x1         x2        x3        x4        x5         x6  \
# 0 -0.166563 -3.961588   4.621113  2.481908 -1.800135  0.804684   6.718751
# 1 -0.149894 -0.585676  27.839856  4.152333  6.426802 -2.426943  40.477058
#
#           x7        x8        x9  ...        x41       x42       x43  \
# 0 -14.789997 -1.040673 -4.204950  ...  -1.497117  5.414063 -2.325655
# 1  -6.725709  0.896421  0.330165  ...  36.292790  4.490915  0.762561
#
#         x44       x45        x46       x47       x48        x49  y
# 0  1.674827 -0.264332  60.781427 -7.689696  0.151589  -8.040166  0
# 1  6.526662  1.007927  15.805696 -4.896678 -0.320283  16.719974  0
#
# [2 rows x 51 columns]

# %%
object_columns = df.select_dtypes(include=[object]).columns.tolist()
df.loc[:,object_columns] = df.loc[:,object_columns].astype("category")
df.info()

# %%
train_df, val_df, test_df = create_train_val_test_sets(df=df, 
                                                       target_column="y", 
                                                       test_size=0.1, 
                                                       val_size=0.1, 
                                                       random_state=7742)
# Out:
# Train Shape: (128000, 51)
# Val Shape: (16000, 51)
# Test Shape: (16000, 51)

# %%
X_train = train_df.drop(columns="y")
y_train = train_df.loc[:,"y"].to_numpy()

X_val = val_df.drop(columns="y")
y_val = val_df.loc[:,"y"].to_numpy()

X_test = test_df.drop(columns="y")
y_test = test_df.loc[:,"y"].to_numpy()

# Subset to features selected by DAI
X_train_dai, X_val_dai, X_test_dai = subset_to_dai_selected_features(X_train=X_train, 
                                                                     X_val=X_val, 
                                                                     X_test=X_test)
# Out:
# DAI Train Shape: (128000, 17)
# DAI Val Shape: (16000, 17)
# DAI Test Shape: (16000, 17)

# %%
scorers_dict = {"accuracy":"accuracy", 
                "f025_score":make_scorer(fbeta_score, beta=0.25),
                "f05_score":make_scorer(fbeta_score, beta=0.5), 
                "avg_dollars_lost_per_prediction":make_scorer(score_func=average_dollars_scorer_sklearn, 
                                                              greater_is_better=False), 
                "best_iter_early_stopping":get_lgbm_best_iter_sklearn}

# %%
# %%time

parameter_grid = {"model__boosting_type":["gbdt"], 
                  "model__colsample_bytree":[0.9, 1.0], 
                  "model__bagging_seed":[7742], 
                  "model__feature_fraction_seed":[7743], 
                  "model__importance_type":["gain"], 
                  "model__learning_rate":[0.005, 0.0055, 
                                          0.006, 0.0065, 
                                          0.007, 0.0075, 
                                          0.008, 0.0085], 
                  "model__max_bin":[510, 1020], 
                  "model__max_delta_step":[0.0], 
                  "model__max_depth":[-1, 30], 
                  "model__num_leaves":[1024, 2048], 
                  "model__min_child_samples":[20], 
                  "model__min_child_weight":[0.001], 
                  "model__min_data_in_bin":[1], 
                  "model__min_split_gain":[0.0],
                  "model__n_estimators":[7_500], 
                  "model__objective":["binary"], 
                  "model__reg_alpha":[0.0], 
                  "model__reg_lambda":[1.0, 2.0, 5.0], 
                  "model__scale_pos_weight":[1.0], 
                  "model__seed":[534401655], 
                  "model__subsample":[0.7, 0.8], 
                  "model__subsample_freq":[1]}

cv_splitter = StratifiedKFold(n_splits=5, 
                              shuffle=True, 
                              random_state=7742)

model_pipe = Pipeline(steps=[("impute", SimpleImputer(strategy="mean")), 
                             ('model', LGBMClassifier(n_jobs=32, random_state=7742))])


gs_no_mono = GridSearchCV(estimator=model_pipe, 
                  param_grid=parameter_grid, 
                  refit="avg_dollars_lost_per_prediction",
                  scoring=scorers_dict, 
                  cv=cv_splitter,
                  n_jobs=32, 
                  error_score="raise", 
                  return_train_score=True, 
                  verbose=2)

# gs_no_mono.fit(X=X_train_dai, 
#        y=y_train, 
#        model__callbacks=[early_stopping(stopping_rounds=5, 
#                                         first_metric_only=True, 
#                                         verbose=True)], 
#        model__eval_metric=[average_dollars_scorer_lgbm, 
#                            "binary"], 
#        model__eval_set=[(X_val_dai, y_val)])


# save_name = get_gs_save_name(model_name="LGBM_GS_No_Mono")
# save_path=f"./models/{save_name}"
# with open(save_path, 'wb') as file:
#     pickle.dump(gs_no_mono, file)

    
PATH=f"./models/LGBM_GS_No_Mono_20221124_0625.pkl"
gs_no_mono = load_gs_from_pickle(pickle_filepath=PATH)

gs_df = gs_to_clean_df(gs_no_mono.cv_results_, 
                       sort_metric="mean_test_avg_dollars_lost_per_prediction", 
                       sort_ascending=False)
gs_df.loc[:,[c for c in gs_df.columns if "std" not in c]].head()
# Out:
# CPU times: total: 21.8 s
# Wall time: 1.17 s
#     bagging_seed boosting_type colsample_bytree feature_fraction_seed  \
# 406         7742          gbdt              1.0                  7743
# 385         7742          gbdt              1.0                  7743
# 452         7742          gbdt              1.0                  7743
# 584         7742          gbdt              1.0                  7743
# 588         7742          gbdt              1.0                  7743
#
#     importance_type learning_rate max_bin max_delta_step max_depth  \
# 406            gain         0.005     510            0.0        30
# 385            gain         0.005     510            0.0        -1
# 452            gain        0.0055     510            0.0        30
# 584            gain         0.007     510            0.0        -1
# 588            gain         0.007     510            0.0        30
#
#     min_child_samples  ... mean_train_f025_score mean_test_f05_score  \
# 406                20  ...              0.998465            0.947904
# 385                20  ...              0.999819            0.947794
# 452                20  ...              0.999458            0.947734
# 584                20  ...              0.999380            0.947744
# 588                20  ...              0.999729            0.947740
#
#     rank_test_f05_score mean_train_f05_score  \
# 406                   1             0.998360
# 385                   2             0.999816
# 452                   8             0.999418
# 584                   5             0.999342
# 588                   6             0.999709
#
#     mean_test_avg_dollars_lost_per_prediction  \
# 406                                 -2.463281
# 385                                 -2.465156
# 452                                 -2.468281
# 584                                 -2.469375
# 588                                 -2.469531
#
#     rank_test_avg_dollars_lost_per_prediction  \
# 406                                         1
# 385                                         2
# 452                                         3
# 584                                         4
# 588                                         5
#
#     mean_train_avg_dollars_lost_per_prediction  \
# 406                                  -0.077734
# 385                                  -0.008828
# 452                                  -0.027578
# 584                                  -0.031250
# 588                                  -0.013789
#
#     mean_test_best_iter_early_stopping rank_test_best_iter_early_stopping  \
# 406                             3091.8                                  6
# 385                             2024.4                                275
# 452                             2189.0                                181
# 584                             1687.0                                493
# 588                             1561.6                                565
#
#     mean_train_best_iter_early_stopping
# 406                              3091.8
# 385                              2024.4
# 452                              2189.0
# 584                              1687.0
# 588                              1561.6
#
# [5 rows x 37 columns]

# %%
gs_df.sort_values(by="mean_test_accuracy", ascending=False).head(3)
# Out:
#     bagging_seed boosting_type colsample_bytree feature_fraction_seed  \
# 406         7742          gbdt              1.0                  7743
# 388         7742          gbdt              1.0                  7743
# 626         7742          gbdt              1.0                  7743
#
#     importance_type learning_rate max_bin max_delta_step max_depth  \
# 406            gain         0.005     510            0.0        30
# 388            gain         0.005     510            0.0        -1
# 626            gain        0.0075     510            0.0        -1
#
#     min_child_samples min_child_weight min_data_in_bin n_estimators  \
# 406                20            0.001               1         7500
# 388                20            0.001               1         7500
# 626                20            0.001               1         7500
#
#     num_leaves objective reg_alpha reg_lambda scale_pos_weight       seed  \
# 406       2048    binary       0.0        5.0              1.0  534401655
# 388       1024    binary       0.0        5.0              1.0  534401655
# 626       1024    binary       0.0        2.0              1.0  534401655
#
#     subsample subsample_freq  \
# 406       0.7              1
# 388       0.7              1
# 626       0.7              1
#
#                                                 params  mean_test_accuracy  \
# 406  {'model__bagging_seed': 7742, 'model__boosting...            0.955617
# 388  {'model__bagging_seed': 7742, 'model__boosting...            0.955500
# 626  {'model__bagging_seed': 7742, 'model__boosting...            0.955500
#
#      std_test_accuracy  rank_test_accuracy  mean_train_accuracy  \
# 406           0.001630                   1             0.998504
# 388           0.001452                   2             0.998137
# 626           0.001404                   2             0.999188
#
#      std_train_accuracy  mean_test_f025_score  std_test_f025_score  \
# 406            0.000234              0.949589             0.000969
# 388            0.000246              0.949403             0.000806
# 626            0.000142              0.949435             0.000897
#
#      rank_test_f025_score  mean_train_f025_score  std_train_f025_score  \
# 406                     2               0.998465              0.000238
# 388                    21               0.998097              0.000274
# 626                    13               0.999138              0.000189
#
#      mean_test_f05_score  std_test_f05_score  rank_test_f05_score  \
# 406             0.947904            0.001274                    1
# 388             0.947731            0.001114                    9
# 626             0.947752            0.001067                    4
#
#      mean_train_f05_score  std_train_f05_score  \
# 406              0.998360             0.000254
# 388              0.997963             0.000284
# 626              0.999089             0.000184
#
#      mean_test_avg_dollars_lost_per_prediction  \
# 406                                  -2.463281
# 388                                  -2.471875
# 626                                  -2.470625
#
#      std_test_avg_dollars_lost_per_prediction  \
# 406                                  0.051704
# 388                                  0.044335
# 626                                  0.044892
#
#      rank_test_avg_dollars_lost_per_prediction  \
# 406                                          1
# 388                                         13
# 626                                          8
#
#      mean_train_avg_dollars_lost_per_prediction  \
# 406                                   -0.077734
# 388                                   -0.096484
# 626                                   -0.043281
#
#      std_train_avg_dollars_lost_per_prediction  \
# 406                                   0.012023
# 388                                   0.013546
# 626                                   0.008891
#
#      mean_test_best_iter_early_stopping  std_test_best_iter_early_stopping  \
# 406                              3091.8                         120.791390
# 388                              2945.2                         111.377556
# 626                              1598.4                          38.160713
#
#      rank_test_best_iter_early_stopping  mean_train_best_iter_early_stopping  \
# 406                                   6                               3091.8
# 388                                  22                               2945.2
# 626                                 540                               1598.4
#
#      std_train_best_iter_early_stopping
# 406                          120.791390
# 388                          111.377556
# 626                           38.160713

# %%
gs_no_mono.best_score_
# Out:
# -2.4632812500000005

# %%
gs_no_mono.best_estimator_.named_steps['model'].best_iteration_
# Out:
# 2994

# %%
MODEL_NAME="Gridsearch No Mono"
dai_train_pred_df, dai_val_pred_df = get_val_performance_after_all_train_refit(gs=gs_no_mono, 
                                                                               X_train=X_train_dai, 
                                                                               y_train=y_train, 
                                                                               X_val=X_val_dai, 
                                                                               y_val=y_val, 
                                                                               model_name=MODEL_NAME)
# Out:
# ================= Gridsearch No Mono =================
# Best Iteration: 2994
# accuracy: Train=0.9982578125, Validation=0.95275
# f025_score: Train=0.9982654453322939, Validation=0.9483284375437124
# f05_score: Train=0.998125384861216, Validation=0.9458305663599278
# avg_dollars_lost_per_prediction: Train=0.08859375, Validation=2.54
# ======================================================

# %%
gs_no_mono.best_params_

# %%
# %%time

parameter_grid = {"model__boosting_type":["gbdt"], 
                  "model__colsample_bytree":[1.0], 
                  "model__bagging_seed":[7742], 
                  "model__feature_fraction_seed":[7743], 
                  "model__importance_type":["gain"], 
                  "model__learning_rate":[0.001, 0.005], 
                  "model__max_bin":[510], 
                  "model__max_delta_step":[0.0], 
                  "model__max_depth":[30], 
                  "model__num_leaves":[2048], 
                  "model__min_child_samples":[20], 
                  "model__min_child_weight":[0.001], 
                  "model__min_data_in_bin":[1], 
                  "model__min_split_gain":[0.0],
                  "model__n_estimators":[7_500], 
                  "model__objective":["binary"], 
                  "model__reg_alpha":[0.0], 
                  "model__reg_lambda":[5.0 + num for num in range(101)], 
                  "model__scale_pos_weight":[1.0], 
                  "model__seed":[534401655], 
                  "model__subsample":[0.7], 
                  "model__subsample_freq":[1]}

cv_splitter = StratifiedKFold(n_splits=5, 
                              shuffle=True, 
                              random_state=7742)

model_pipe = Pipeline(steps=[("impute", SimpleImputer(strategy="mean")), 
                             ('model', LGBMClassifier(n_jobs=32, random_state=7742))])


gs_no_mono_reg = GridSearchCV(estimator=model_pipe, 
                  param_grid=parameter_grid, 
                  refit="avg_dollars_lost_per_prediction",
                  scoring=scorers_dict, 
                  cv=cv_splitter,
                  n_jobs=32, 
                  error_score="raise", 
                  return_train_score=True, 
                  verbose=2)

# gs_no_mono_reg.fit(X=X_train_dai, 
#        y=y_train, 
#        model__callbacks=[early_stopping(stopping_rounds=5, 
#                                         first_metric_only=True, 
#                                         verbose=True)], 
#        model__eval_metric=[average_dollars_scorer_lgbm, 
#                            "binary"], 
#        model__eval_set=[(X_val_dai, y_val)])


# save_name = get_gs_save_name(model_name="LGBM_GS_No_Mono_Reg")
# save_path=f"./models/{save_name}"
# with open(save_path, 'wb') as file:
#     pickle.dump(gs_no_mono_reg, file)

    
PATH=f"./models/LGBM_GS_No_Mono_Reg_20221126_1049.pkl"
g_reg = load_gs_from_pickle(pickle_filepath=PATH)

gs_df = gs_to_clean_df(gs_no_mono_reg.cv_results_, 
                       sort_metric="mean_test_avg_dollars_lost_per_prediction", 
                       sort_ascending=False)
gs_df.loc[:,[c for c in gs_df.columns if "std" not in c]].head()
# Out:
# Fitting 5 folds for each of 202 candidates, totalling 1010 fits
# [LightGBM] [Warning] seed is set=534401655, random_state=7742 will be ignored. Current value: seed=534401655
# Training until validation scores don't improve for 5 rounds
# Early stopping, best iteration is:
# [2994]	valid_0's binary_logloss: 0.130106	valid_0's avg_dollars_lost_per_prediction: 2.54125
# Evaluated only: binary_logloss
# CPU times: total: 1h 12min 59s
# Wall time: 1d 1h 19min 30s
#     bagging_seed boosting_type colsample_bytree feature_fraction_seed  \
# 101         7742          gbdt              1.0                  7743
# 104         7742          gbdt              1.0                  7743
# 103         7742          gbdt              1.0                  7743
# 102         7742          gbdt              1.0                  7743
# 105         7742          gbdt              1.0                  7743
#
#     importance_type learning_rate max_bin max_delta_step max_depth  \
# 101            gain         0.005     510            0.0        30
# 104            gain         0.005     510            0.0        30
# 103            gain         0.005     510            0.0        30
# 102            gain         0.005     510            0.0        30
# 105            gain         0.005     510            0.0        30
#
#     min_child_samples  ... mean_train_f025_score mean_test_f05_score  \
# 101                20  ...              0.998465            0.947904
# 104                20  ...              0.997895            0.947591
# 103                20  ...              0.998036            0.947539
# 102                20  ...              0.998272            0.947553
# 105                20  ...              0.997327            0.947335
#
#     rank_test_f05_score mean_train_f05_score  \
# 101                   1             0.998360
# 104                   2             0.997742
# 103                   4             0.997896
# 102                   3             0.998146
# 105                   5             0.997156
#
#     mean_test_avg_dollars_lost_per_prediction  \
# 101                                 -2.463281
# 104                                 -2.479375
# 103                                 -2.481094
# 102                                 -2.482656
# 105                                 -2.492188
#
#     rank_test_avg_dollars_lost_per_prediction  \
# 101                                         1
# 104                                         2
# 103                                         3
# 102                                         4
# 105                                         5
#
#     mean_train_avg_dollars_lost_per_prediction  \
# 101                                  -0.077734
# 104                                  -0.106875
# 103                                  -0.099609
# 102                                  -0.087773
# 105                                  -0.134844
#
#     mean_test_best_iter_early_stopping rank_test_best_iter_early_stopping  \
# 101                             3091.8                                202
# 104                             3606.2                                198
# 103                             3428.4                                200
# 102                             3270.0                                201
# 105                             3585.6                                199
#
#     mean_train_best_iter_early_stopping
# 101                              3091.8
# 104                              3606.2
# 103                              3428.4
# 102                              3270.0
# 105                              3585.6
#
# [5 rows x 37 columns]

# %%
gs_df = gs_to_clean_df(gs_no_mono_reg.cv_results_, 
                       sort_metric="mean_test_avg_dollars_lost_per_prediction", 
                       sort_ascending=False)
gs_df.loc[:,[c for c in gs_df.columns if "std" not in c]].head()
# Out:
#     bagging_seed boosting_type colsample_bytree feature_fraction_seed  \
# 101         7742          gbdt              1.0                  7743
# 104         7742          gbdt              1.0                  7743
# 103         7742          gbdt              1.0                  7743
# 102         7742          gbdt              1.0                  7743
# 105         7742          gbdt              1.0                  7743
#
#     importance_type learning_rate max_bin max_delta_step max_depth  \
# 101            gain         0.005     510            0.0        30
# 104            gain         0.005     510            0.0        30
# 103            gain         0.005     510            0.0        30
# 102            gain         0.005     510            0.0        30
# 105            gain         0.005     510            0.0        30
#
#     min_child_samples min_child_weight min_data_in_bin n_estimators  \
# 101                20            0.001               1         7500
# 104                20            0.001               1         7500
# 103                20            0.001               1         7500
# 102                20            0.001               1         7500
# 105                20            0.001               1         7500
#
#     num_leaves objective reg_alpha reg_lambda scale_pos_weight       seed  \
# 101       2048    binary       0.0        5.0              1.0  534401655
# 104       2048    binary       0.0        8.0              1.0  534401655
# 103       2048    binary       0.0        7.0              1.0  534401655
# 102       2048    binary       0.0        6.0              1.0  534401655
# 105       2048    binary       0.0        9.0              1.0  534401655
#
#     subsample subsample_freq  \
# 101       0.7              1
# 104       0.7              1
# 103       0.7              1
# 102       0.7              1
# 105       0.7              1
#
#                                                 params  mean_test_accuracy  \
# 101  {'model__bagging_seed': 7742, 'model__boosting...            0.955617
# 104  {'model__bagging_seed': 7742, 'model__boosting...            0.955438
# 103  {'model__bagging_seed': 7742, 'model__boosting...            0.955352
# 102  {'model__bagging_seed': 7742, 'model__boosting...            0.955492
# 105  {'model__bagging_seed': 7742, 'model__boosting...            0.955266
#
#      rank_test_accuracy  mean_train_accuracy  mean_test_f025_score  \
# 101                   1             0.998504              0.949589
# 104                   3             0.997930              0.949231
# 103                   4             0.998074              0.949208
# 102                   2             0.998299              0.949137
# 105                   6             0.997430              0.948953
#
#      rank_test_f025_score  mean_train_f025_score  mean_test_f05_score  \
# 101                     1               0.998465             0.947904
# 104                     2               0.997895             0.947591
# 103                     3               0.998036             0.947539
# 102                     4               0.998272             0.947553
# 105                     5               0.997327             0.947335
#
#      rank_test_f05_score  mean_train_f05_score  \
# 101                    1              0.998360
# 104                    2              0.997742
# 103                    4              0.997896
# 102                    3              0.998146
# 105                    5              0.997156
#
#      mean_test_avg_dollars_lost_per_prediction  \
# 101                                  -2.463281
# 104                                  -2.479375
# 103                                  -2.481094
# 102                                  -2.482656
# 105                                  -2.492188
#
#      rank_test_avg_dollars_lost_per_prediction  \
# 101                                          1
# 104                                          2
# 103                                          3
# 102                                          4
# 105                                          5
#
#      mean_train_avg_dollars_lost_per_prediction  \
# 101                                   -0.077734
# 104                                   -0.106875
# 103                                   -0.099609
# 102                                   -0.087773
# 105                                   -0.134844
#
#      mean_test_best_iter_early_stopping  rank_test_best_iter_early_stopping  \
# 101                              3091.8                                 202
# 104                              3606.2                                 198
# 103                              3428.4                                 200
# 102                              3270.0                                 201
# 105                              3585.6                                 199
#
#      mean_train_best_iter_early_stopping
# 101                               3091.8
# 104                               3606.2
# 103                               3428.4
# 102                               3270.0
# 105                               3585.6

# %%
MODEL_NAME="Gridsearch No Mono Reg"
dai_train_reg_pred_df, dai_val_reg_pred_df = get_val_performance_after_all_train_refit(gs=gs_no_mono_reg, 
                                                                               X_train=X_train_dai, 
                                                                               y_train=y_train, 
                                                                               X_val=X_val_dai, 
                                                                               y_val=y_val, 
                                                                               model_name=MODEL_NAME)
# Out:
# ================= Gridsearch No Mono Reg =================
# Best Iteration: 2994
# accuracy: Train=0.9982578125, Validation=0.95275
# f025_score: Train=0.9982654453322939, Validation=0.9483284375437124
# f05_score: Train=0.998125384861216, Validation=0.9458305663599278
# avg_dollars_lost_per_prediction: Train=0.08859375, Validation=2.54
# ==========================================================

# %%
metric_cols = [c for c in gs_df.columns if ("train" in c or "test" in c) and "std" not in c and "rank" not in c and "f025" not in c]
c = ["reg_lambda"] + metric_cols
gs_df.loc[:, c].head(20)
# Out:
#     reg_lambda  mean_test_accuracy  mean_train_accuracy  mean_test_f05_score  \
# 101        5.0            0.955617             0.998504             0.947904
# 104        8.0            0.955438             0.997930             0.947591
# 103        7.0            0.955352             0.998074             0.947539
# 102        6.0            0.955492             0.998299             0.947553
# 105        9.0            0.955266             0.997430             0.947335
# 106       10.0            0.955242             0.997502             0.947311
# 108       12.0            0.955297             0.997510             0.947283
# 107       11.0            0.955031             0.997168             0.947020
# 109       13.0            0.955125             0.997215             0.947006
# 112       16.0            0.955117             0.997096             0.946970
# 110       14.0            0.955000             0.996955             0.946920
# 111       15.0            0.955094             0.996912             0.946926
# 117       21.0            0.955000             0.996676             0.946889
# 115       19.0            0.954937             0.996473             0.946820
# 119       23.0            0.954859             0.996025             0.946721
# 116       20.0            0.954883             0.996576             0.946686
# 113       17.0            0.954789             0.996475             0.946639
# 118       22.0            0.954859             0.996283             0.946621
# 120       24.0            0.954789             0.995859             0.946578
# 114       18.0            0.954758             0.996648             0.946549
#
#      mean_train_f05_score  mean_test_avg_dollars_lost_per_prediction  \
# 101              0.998360                                  -2.463281
# 104              0.997742                                  -2.479375
# 103              0.997896                                  -2.481094
# 102              0.998146                                  -2.482656
# 105              0.997156                                  -2.492188
# 106              0.997257                                  -2.493281
# 108              0.997261                                  -2.495938
# 107              0.996862                                  -2.507500
# 109              0.996932                                  -2.510000
# 112              0.996759                                  -2.512031
# 110              0.996606                                  -2.513125
# 111              0.996573                                  -2.514375
# 117              0.996303                                  -2.515000
# 115              0.996052                                  -2.518125
# 119              0.995556                                  -2.522812
# 116              0.996166                                  -2.525469
# 113              0.996068                                  -2.526719
# 118              0.995849                                  -2.529063
# 120              0.995368                                  -2.530469
# 114              0.996254                                  -2.531719
#
#      mean_train_avg_dollars_lost_per_prediction  \
# 101                                   -0.077734
# 104                                   -0.106875
# 103                                   -0.099609
# 102                                   -0.087773
# 105                                   -0.134844
# 106                                   -0.129961
# 108                                   -0.129805
# 107                                   -0.148828
# 109                                   -0.145391
# 112                                   -0.153867
# 110                                   -0.161055
# 111                                   -0.162539
# 117                                   -0.175391
# 115                                   -0.187422
# 119                                   -0.210898
# 116                                   -0.182070
# 113                                   -0.186602
# 118                                   -0.196992
# 120                                   -0.219844
# 114                                   -0.177812
#
#      mean_test_best_iter_early_stopping  mean_train_best_iter_early_stopping
# 101                              3091.8                               3091.8
# 104                              3606.2                               3606.2
# 103                              3428.4                               3428.4
# 102                              3270.0                               3270.0
# 105                              3585.6                               3585.6
# 106                              3828.0                               3828.0
# 108                              4286.6                               4286.6
# 107                              3856.2                               3856.2
# 109                              4320.4                               4320.4
# 112                              4844.2                               4844.2
# 110                              4349.0                               4349.0
# 111                              4504.8                               4504.8
# 117                              5471.6                               5471.6
# 115                              4968.8                               4968.8
# 119                              5338.2                               5338.2
# 116                              5197.6                               5197.6
# 113                              4585.4                               4585.4
# 118                              5353.2                               5353.2
# 120                              5411.4                               5411.4
# 114                              4881.2                               4881.2

# %% [markdown]
# ### For single models

# %%
grid = {"model__boosting_type":["gbdt"], 
                  "model__colsample_bytree":[0.8], 
                  "model__bagging_seed":[7742], 
                  "model__feature_fraction_seed":[7743], 
                  "model__importance_type":["gain"], 
                  "model__learning_rate":[0.01], 
                  "model__max_bin":[63], 
                  "model__max_delta_step":[0.0], 
                  "model__max_depth":[30], 
                  "model__num_leaves":[2048], 
                  "model__min_child_samples":[20], 
                  "model__min_child_weight":[0.001], 
                  "model__min_data_in_bin":[1], 
                  "model__min_split_gain":[0.0],
                  "model__n_estimators":[7_500], 
                  "model__objective":["binary"], 
                  "model__reg_alpha":[0.0], 
                  "model__reg_lambda":[5.0], 
                  "model__scale_pos_weight":[1.0], 
                  "model__seed":[534401655], 
                  "model__subsample":[0.7], 
                  "model__subsample_freq":[1]}

cv_splitter = StratifiedKFold(n_splits=5, 
                              shuffle=True, 
                              random_state=7742)

model_pipe = Pipeline(steps=[("impute", SimpleImputer(strategy="mean")), 
                             ('model', LGBMClassifier(n_jobs=32, random_state=7742))])


g_test = GridSearchCV(estimator=model_pipe, 
                  param_grid=grid, 
                  refit="avg_dollars_lost_per_prediction",
                  scoring=scorers_dict, 
                  cv=cv_splitter,
                  n_jobs=32, 
                  error_score="raise", 
                  return_train_score=True, 
                  verbose=2)

# g_test.fit(X=X_train_dai, 
#        y=y_train, 
#        model__callbacks=[early_stopping(stopping_rounds=5, 
#                                         first_metric_only=True, 
#                                         verbose=True)], 
#        model__eval_metric=[average_dollars_scorer_lgbm, 
#                            "binary"], 
#        model__eval_set=[(X_val_dai, y_val)])
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [LightGBM] [Warning] seed is set=534401655, random_state=7742 will be ignored. Current value: seed=534401655
# Training until validation scores don't improve for 5 rounds
# Early stopping, best iteration is:
# [1711]	valid_0's binary_logloss: 0.129392	valid_0's avg_dollars_lost_per_prediction: 2.4625
# Evaluated only: binary_logloss
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=7742, shuffle=True),
#              error_score='raise',
#              estimator=Pipeline(steps=[('impute', SimpleImputer()),
#                                        ('model',
#                                         LGBMClassifier(n_jobs=32,
#                                                        random_state=7742))]),
#              n_jobs=32,
#              param_grid={'model__bagging_seed': [7742],
#                          'model__boosting_type': ['gbdt'],
#                          'model__colsample_bytree': [0.8],
#                          'model__feature_fraction_seed':...
#              refit='avg_dollars_lost_per_prediction', return_train_score=True,
#              scoring={'accuracy': 'accuracy',
#                       'avg_dollars_lost_per_prediction': make_scorer(average_dollars_scorer_sklearn, greater_is_better=False),
#                       'best_iter_early_stopping': <function get_lgbm_best_iter_sklearn at 0x00000160394BB880>,
#                       'f025_score': make_scorer(fbeta_score, beta=0.25),
#                       'f05_score': make_scorer(fbeta_score, beta=0.5)},
#              verbose=2)

# %%
MODEL_NAME="Gridsearch Test"
dai_train_reg_pred_df, dai_val_reg_pred_df = get_val_performance_after_all_train_refit(gs=g_test, 
                                                                               X_train=X_train_dai, 
                                                                               y_train=y_train, 
                                                                               X_val=X_val_dai, 
                                                                               y_val=y_val, 
                                                                               model_name=MODEL_NAME)
# Out:
# ================= Gridsearch Test =================
# Best Iteration: 1711
# accuracy: Train=0.9983125, Validation=0.9539375
# f025_score: Train=0.9983079565021014, Validation=0.9500219243005215
# f05_score: Train=0.9981761354336355, Validation=0.9474549998418271
# avg_dollars_lost_per_prediction: Train=0.08625, Validation=2.46125
# ===================================================

# %%
g_df = gs_to_clean_df(g_test.cv_results_, 
                       sort_metric="mean_test_avg_dollars_lost_per_prediction", 
                       sort_ascending=False)
metric_cols = [c for c in g_df.columns if ("train" in c or "test" in c) and "std" not in c and "rank" not in c and "f025" not in c]
c = ["reg_lambda"] + metric_cols
g_df.loc[:, c].head(20)
# Out:
#   reg_lambda  mean_test_accuracy  mean_train_accuracy  mean_test_f05_score  \
# 0        5.0            0.955383             0.998021             0.947457
#
#    mean_train_f05_score  mean_test_avg_dollars_lost_per_prediction  \
# 0               0.99785                                  -2.486719
#
#    mean_train_avg_dollars_lost_per_prediction  \
# 0                                   -0.101758
#
#    mean_test_best_iter_early_stopping  mean_train_best_iter_early_stopping
# 0                              3277.2                               3277.2
