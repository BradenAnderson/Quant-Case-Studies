# %%
from spam import *
import plotly.express as px

# %%
df = pd.read_csv("./initial_preprocess_emails_092722_full.csv")

# %%
df.head(2)
# Out:
#                                                 text  \
# 0       Date:        Wed, 21 Aug 2002 10:54:46 -0...
# 1   Martin A posted:\nTassos Papadopoulos, the Gr...
#
#                                       text_clean_lp1  \
# 0  date wed 21 aug 2002 105446 0500 from chris ga...
# 1  martin a posted tassos papadopoulos the greek ...
#
#                                       text_clean_lp2  \
# 0  date wed 21 aug 2002 105446 0500 from chris ga...
# 1  martin a posted tassos papadopoulos the greek ...
#
#                                       text_clean_lpn  \
# 0  date wed  aug    from chris garrigues cwgdated...
# 1  martin a posted tassos papadopoulos the greek ...
#
#                                       text_clean_lpa  \
# 0  date wed  aug    from chris garrigues cwgdated...
# 1  martin a posted tassos papadopoulos the greek ...
#
#                                      text_clean_lp1c  \
# 0  date wednesday 21 aug 2002 105446 0500 from ch...
# ...

# %%
f_dists = get_all_freq_dicts(df=df, 
                             text_columns=[col for col in df.columns if col.startswith("text")])
print(f_dists.keys())

# %%
f_dists['text']['label_0'].most_common(5)

# %%
# fd = load_gs_from_pickle(pickle_filepath="./word_counts/word_counts_20220926_1505.pkl")
# fd['text']['label_0'].most_common(5)
